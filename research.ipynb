# %%
import pathlib
import datetime as dt
import pandas as pd
import dask.dataframe as dd

from dask.distributed import Client, wait
from common import trim_memory, select_and_sort

from dask_ml.decomposition import PCA
from transformers import ColumnsCorrector
from sklearn.pipeline import make_pipeline
from sklearn.utils.class_weight import compute_class_weight
from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier
from sklearn.metrics import f1_score

data_folder = pathlib.Path('data')

# %%
client = Client(n_workers=1)
client
# Out:
# 2022-05-24 23:06:47,239 - distributed.diskutils - INFO - Found stale lock file and directory '/home/avagadro/projects/gb_megafon/dask-worker-space/worker-5p8kka9n', purging
# <Client: 'tcp://127.0.0.1:42245' processes=1 threads=8, memory=15.59 GiB>

# %%
# parameters
blocksize = '200MB'
drop_feats = ['75', '81', '85', '139', '203']

# with PCA compression: 0.7776868306270386
bound_date = '2018-11-19'
compress_features = True
n_components = 3

# %%
# # baseline
# bound_date = ''
# compress_features = False

# # partial fit: 0.7776767294528835
# bound_date = '2018-11-19'
# compress_features = False

# %% [markdown]
# ## load and prepare data

# %%
# read train data
train_data = dd.read_csv(data_folder.joinpath('data_train.csv'), blocksize=blocksize).drop('Unnamed: 0', axis=1)

# select required train part
if bound_date:
    bound_timestamp = dt.datetime.fromisoformat(bound_date).timestamp()
    used_train_mask = client.submit(lambda df, bound: df['buy_time'] >= bound, train_data, bound_timestamp, key='get_train_data_mask')
    # extract and sort train data
    train_data = client.submit(select_and_sort, train_data, mask=used_train_mask, by='buy_time', key='train_data_sort')
else:
    train_data = client.submit(train_data.sort_values, by='buy_time', key='train_data_sort')

# %%
# read features
feats_csv = dd.read_csv(data_folder.joinpath('features.csv'), sep='\t', blocksize=blocksize).drop(['Unnamed: 0', *drop_feats], axis=1)

# compress if required
if compress_features:
    # push dask data to the cluster separately
    features = client.scatter(feats_csv.drop(['id', 'buy_time'], axis=1))
    headers = client.submit(feats_csv[['id', 'buy_time']].compute, key='compute_headers')

    # recast to dask array with computes sizes
    dask_array = client.submit(dd.DataFrame.to_dask_array, features, lengths=True, key='recast_to_dask_array')

    # fit PCA
    pca_model = PCA(n_components)
    fit_pca = client.submit(pca_model.fit, dask_array, key='fit_pca_model')
    # trim memory
    client.run(trim_memory)

    # transform features
    transformed = client.submit(lambda df: fit_pca.result().transform(df).compute(), dask_array, key='compress_features')
    wait(transformed)

    # concat features
    concat = client.submit(lambda df, arr: pd.concat([df.reset_index(drop=True), pd.DataFrame(arr)], axis=1), headers, transformed, key='concat_features')
    user_feats = concat.result()
    del features, headers, dask_array, fit_pca, transformed, concat
else:
    user_feats = feats_csv
# Out:
# 2022-05-24 23:59:22,400 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 12.47 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:22,566 - distributed.worker_memory - WARNING - Worker is at 79% memory usage. Resuming worker. Process memory: 12.45 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:22,668 - distributed.worker_memory - WARNING - Worker is at 80% memory usage. Pausing worker.  Process memory: 12.50 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:25,977 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.44 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:25,979 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.45 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:25,982 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.45 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.56 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.57 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,278 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.61 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,380 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.60 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,484 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.52 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,580 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.53 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,680 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.60 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,778 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.60 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.64 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:26,982 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.64 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,078 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.67 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,178 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.68 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,278 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.70 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,379 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.72 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,481 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.74 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,580 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.75 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,679 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.76 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,779 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.78 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,878 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.79 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:27,982 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.79 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.78 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.78 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,278 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.78 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,378 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.76 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,481 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.77 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,578 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.78 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,678 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.81 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,780 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.83 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.86 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:28,980 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.87 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.88 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,178 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.88 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,278 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,379 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,481 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,578 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,679 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,779 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.84 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.82 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:29,980 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.88 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.88 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,278 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,378 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,481 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,578 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,680 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.89 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,779 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.90 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.91 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:30,987 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.91 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.92 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.92 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,279 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.92 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,379 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.93 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,480 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.94 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,580 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.95 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,679 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.96 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,779 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.96 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,879 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.96 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:31,980 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.97 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:32,079 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.98 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:32,179 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.98 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:32,279 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.98 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:32,378 - distributed.worker_memory - WARNING - Unmanaged memory use is high. This may indicate a memory leak or the memory may not be released to the OS; see https://distributed.dask.org/en/latest/worker.html#memtrim for more information. -- Unmanaged memory: 13.99 GiB -- Worker memory limit: 15.59 GiB
# 2022-05-24 23:59:32,580 - distributed.worker_memory - WARNING - Worker is at 38% memory usage. Resuming worker. Process memory: 6.00 GiB -- Worker memory limit: 15.59 GiB

# %%
# select required user features
unique_ids = client.submit(lambda df: df['id'].unique().compute(), train_data, key='unique_ids_compute')
used_feats_mask = client.submit(user_feats['id'].isin, unique_ids, key='get_used_feats_mask')

# extract and sort user features
user_feats = client.submit(select_and_sort, user_feats, mask=used_feats_mask, by='buy_time', key='user_feats_sort')

# compute all data (recast to pandas DataFrame)
train_data_df = client.submit(train_data.result().compute, key='recast_train_data')
user_feats_df = user_feats if compress_features else client.submit(user_feats.result().compute, key='recast_user_feats')
wait([train_data_df, user_feats_df])

# remove no longer needed tasks from cluster
del used_train_mask, unique_ids, used_feats_mask, train_data, user_feats

# %%
# merge
merged = client.submit(pd.merge_asof, train_data_df, user_feats_df, by='id', on='buy_time', direction='nearest', key='data_merge')

# split into data/target & send to cluster
data = client.scatter(merged.result().drop('target', axis=1))
target = client.scatter(merged.result()['target'])
wait([data, target])

# remove no longer needed tasks from cluster
del merged, train_data_df, user_feats_df

# %%
# trim cluster memory
client.run(trim_memory)
# Out:
# {'tcp://127.0.0.1:44049': 1}

# %% [markdown]
# ## featuring

# %%
# build featuring pipeline
pipeline = make_pipeline(ColumnsCorrector('drop', ['id', ]), )

# %% [markdown]
# ## fit

# %%
n_folds = 5

metrics = []
models = []
class_weights = dict(enumerate(compute_class_weight('balanced', classes=[0, 1], y=target.result())))
folds = KFold(n_splits=n_folds, shuffle=True, random_state=29)

for train_index, valid_index in folds.split(target.result()):
    # push train/valid dataframes to the cluster
    train_df = client.scatter(data.result().iloc[train_index])
    valid_df = client.scatter(data.result().iloc[valid_index])
    # fit and apply featuring pipeline
    featuring = client.submit(pipeline.fit, train_df, target, key='featuring_fit')
    X_train = client.submit(featuring.result().transform, train_df, key='train_featuring_transform')
    X_valid = client.submit(featuring.result().transform, valid_df, key='valid_featuring_transform')
    # exctract targets and push them to the cluster
    y_train = client.scatter(target.result().iloc[train_index])
    y_valid = client.scatter(target.result().iloc[valid_index])

    # LGBM
    estimator = LGBMClassifier(random_state=17,
                               class_weight=class_weights,
                               n_estimators=100,
                               learning_rate=0.15,
                               max_depth=-1,
                               num_leaves=31,
                               )
    model = client.submit(estimator.fit, X_train, y_train)

    # predicts & metrics
    prediction = client.submit(lambda mdl, df: mdl.predict(df), model, X_valid, key='compute_predictions')
    score = client.submit(f1_score, y_valid, prediction, average='macro', key='scoring')
    # append step result
    models.append(model.result())
    metrics.append(score.result())
    # remove no longer needed tasks from cluster
    del model, featuring, train_df, valid_df, X_train, y_train, X_valid, y_valid, prediction, score
    # trim cluster memory
    client.run(trim_memory)

print(f'Avg. f-score: {sum(metrics) / n_folds}')
# Out:
# Avg. f-score: 0.7776868306270386

# %%
#
